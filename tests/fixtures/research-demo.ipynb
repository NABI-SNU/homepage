# %% [markdown]
# # Demo Notebook
#
# This is a reading-first notebook rendered with **MyST**.
#
# ## Results
#
# :::{note}
# The note block should render as a callout.
# :::
#
# ## Discussion
#
# A final section for the table of contents.

# %%
print('hello from the notebook')
# Out:
# hello from the notebook

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Scatter(x=[0, 1, 2, 3], y=[1, 3, 2, 5], mode='lines+markers')])
fig.update_layout(title='Interactive Demo Plot')
fig
# Out:
# Figure({
#   'data': [{'mode': 'lines+markers', 'name': 'Signal', 'type': 'scatter'}],
#   'layout': {'title': {'text': 'Interactive Demo Plot'}}
# })
